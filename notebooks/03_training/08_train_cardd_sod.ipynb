# %%
from ultralytics import YOLO
from pathlib import Path

DATA_YAML = Path(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\data\processed\cardd_sod_yolo\data.yaml")
print("YAML exists:", DATA_YAML.exists())

model = YOLO(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\models\base\yolo11n-seg.pt")

results = model.train(
    data=str(DATA_YAML),
    imgsz=640,
    epochs=40,
    batch=8,
    device=0,
    workers=0,
    name="cardd_sod_yolo11n_seg"
)
# Out:
# YAML exists: True
# New https://pypi.org/project/ultralytics/8.4.33 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.11.9 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...
