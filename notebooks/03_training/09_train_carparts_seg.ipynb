# %%
from ultralytics import YOLO
from pathlib import Path

print("Starting car parts segmentation training...")
# Out:
# Starting car parts segmentation training...

# %%
from ultralytics import YOLO

model = YOLO(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\models\base\yolo11n-seg.pt")

results = model.train(
    data="carparts-seg.yaml",
    imgsz=640,
    epochs=50,
    batch=8,
    device=0,
    workers=0,
    patience=10,
    name="carparts_yolo11n_seg"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.53 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.11.9 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\models\base\yolo11s-seg.pt")

results = model.train(
    data="carparts-seg.yaml",
    imgsz=640,
    epochs=50,
    batch=8,
    device=0,
    workers=0,
    patience=10,
    name="carparts_yolo11s_seg"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.53 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.11.9 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from ultralytics import YOLO
from pathlib import Path

DATA_YAML = Path(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\data\processed\carparts_seg_yolo\carparts-seg\carparts-seg.yaml")

print("DATA_YAML exists:", DATA_YAML.exists())

model = YOLO(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\notebooks\03_training\runs\segment\carparts_yolo11s_seg2\weights\best.pt")

metrics = model.val(
    data=str(DATA_YAML),
    imgsz=640,
    batch=8,
    device=0,
    workers=0
)
# Out:
# DATA_YAML exists: True
# Ultralytics 8.4.12  Python-3.11.9 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLO11s-seg summary (fused): 114 layers, 10,075,717 parameters, 0 gradients, 32.8 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 90.026.8 MB/s, size: 36.6 KB)
# val: Scanning C:\Users\User\Desktop\Vehicle_Damage_Detection\data\processed\carparts_seg_yolo\carparts-seg\labels\val... 401 images, 12 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 401/401 1.5Kit/s 0.3s0.2s
# val: New cache created: C:\Users\User\Desktop\Vehicle_Damage_Detection\data\processed\carparts_seg_yolo\carparts-seg\labels\val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 6.4it/s 8.0s0.1s
#                    all        401       2042      0.613      0.816       0.73       0.64      0.623      0.831      0.748      0.622
# ...
