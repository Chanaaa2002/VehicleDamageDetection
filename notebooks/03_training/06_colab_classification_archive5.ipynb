# %%
from ultralytics import YOLO
from pathlib import Path

DATA_DIR = Path(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\data\processed\archive5_yolo")
print("DATA_DIR exists:", DATA_DIR.exists())

model = YOLO("yolo11n-cls.pt")

results = model.train(
    data=str(DATA_DIR),
    imgsz=224,
    epochs=30,
    batch=32,
    name="archive5_yolo11n_cls"
)
# Out:
# DATA_DIR exists: True
# ...
# New https://pypi.org/project/ultralytics/8.4.23 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.11.9 torch-2.10.0+cpu CPU (13th Gen Intel Core i7-13650HX)
# ...

# %%
from ultralytics import YOLO
from pathlib import Path

DATA_DIR = Path(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\data\processed\archive5_yolo_aug")

print("DATA_DIR exists:", DATA_DIR.exists())
print("Train exists:", (DATA_DIR / "train").exists())
print("Val exists:", (DATA_DIR / "val").exists())

model = YOLO(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\models\base\yolo11s-cls.pt")

results = model.train(
    data=str(DATA_DIR),
    imgsz=224,
    epochs=60,
    batch=16,
    device=0,
    workers=0,
    name="archive5_yolo11s_cls_aug_balanced"
)
# Out:
# DATA_DIR exists: True
# Train exists: True
# Val exists: True
# New https://pypi.org/project/ultralytics/8.4.50 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.11.9 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...
