# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.10.0+cu128
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
from ultralytics import YOLO
from pathlib import Path

DATA_YAML = Path(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\data\processed\cardd_coco_yolo\data.yaml")
print("YAML exists:", DATA_YAML.exists())

model = YOLO(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\models\base\yolo11s.pt")

results = model.train(
    data=str(DATA_YAML),
    imgsz=640,
    epochs=40,
    batch=8,
    device=0,
    name="cardd_coco_yolo11s_det"
)
# Out:
# YAML exists: True
# ...
# New https://pypi.org/project/ultralytics/8.4.23 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.11.9 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
import json
from pathlib import Path
from collections import Counter

ann_file = Path(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\data\processed\cardd_coco\annotations\instances_train2017.json")

with open(ann_file, "r", encoding="utf-8") as f:
    data = json.load(f)

cat_map = {c["id"]: c["name"] for c in data["categories"]}
counts = Counter()

for ann in data["annotations"]:
    counts[cat_map[ann["category_id"]]] += 1

print("Class counts:")
for cls, cnt in counts.items():
    print(cls, ":", cnt)
# Out:
# Class counts:
# scratch : 2560
# tire flat : 225
# crack : 651
# dent : 1806
# lamp broken : 494
# glass shatter : 475

# %%
from ultralytics import YOLO
from pathlib import Path

DATA_YAML = Path(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\data\processed\cardd_coco_yolo\data.yaml")
print("YAML exists:", DATA_YAML.exists())

model = YOLO(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\models\base\yolo11m.pt")

results = model.train(
    data=str(DATA_YAML),
    imgsz=800,
    epochs=100,
    batch=2,
    device=0,
    workers=0,
    name="cardd_coco_yolo11m_det"
)
# Out:
# YAML exists: True
# ...
# New https://pypi.org/project/ultralytics/8.4.23 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.11.9 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from ultralytics import YOLO
from pathlib import Path

DATA_YAML = Path(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\data\processed\cardd_coco_yolo\data.yaml")
print("YAML exists:", DATA_YAML.exists())

model = YOLO(r"C:\Users\User\Desktop\Vehicle_Damage_Detection\models\base\yolo11s.pt")

results = model.train(
    data=str(DATA_YAML),
    imgsz=800,
    epochs=60,
    batch=4,
    device=0,
    workers=0,
    name="cardd_coco_yolo11s_det_tuned"
)
# Out:
# YAML exists: True
# New https://pypi.org/project/ultralytics/8.4.33 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.11.9 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...
