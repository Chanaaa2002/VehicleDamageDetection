# %%
from pathlib import Path
from ultralytics import YOLO

PROJECT_ROOT = Path(r"C:\Users\User\Desktop\Vehicle_Damage_Detection")

DATA_YAML = PROJECT_ROOT / "data" / "processed" / "damaged_parts_yolo" / "data.yaml"
MODEL_PATH = PROJECT_ROOT / "models" / "base" / "yolo11s.pt"

print("DATA_YAML exists:", DATA_YAML.exists())
print("MODEL_PATH exists:", MODEL_PATH.exists())
print("DATA_YAML:", DATA_YAML)
# Out:
# DATA_YAML exists: True
# MODEL_PATH exists: True
# DATA_YAML: C:\Users\User\Desktop\Vehicle_Damage_Detection\data\processed\damaged_parts_yolo\data.yaml

# %%
model = YOLO(str(MODEL_PATH))

results = model.train(
    data=str(DATA_YAML),
    imgsz=640,
    epochs=60,
    batch=8,
    device=0,
    workers=0,
    patience=10,
    name="damaged_parts_yolo11s_det"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.55 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.11.9 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from pathlib import Path
from ultralytics import YOLO

PROJECT_ROOT = Path(r"C:\Users\User\Desktop\Vehicle_Damage_Detection")

DATA_YAML = PROJECT_ROOT / "data" / "processed" / "damaged_parts_yolo" / "data.yaml"
MODEL_PATH = PROJECT_ROOT / "models" / "base" / "yolo11s.pt"

print("DATA_YAML exists:", DATA_YAML.exists())
print("MODEL_PATH exists:", MODEL_PATH.exists())
print("DATA_YAML:", DATA_YAML)

model = YOLO(str(MODEL_PATH))

results = model.train(
    data=str(DATA_YAML),
    imgsz=640,
    epochs=60,
    batch=8,
    device=0,
    workers=0,
    name="damaged_parts_yolo11s_det_partbox_mirror"
)
# Out:
# DATA_YAML exists: True
# MODEL_PATH exists: True
# DATA_YAML: C:\Users\User\Desktop\Vehicle_Damage_Detection\data\processed\damaged_parts_yolo\data.yaml
# New https://pypi.org/project/ultralytics/8.4.56 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.11.9 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from pathlib import Path
from ultralytics import YOLO

PROJECT_ROOT = Path(r"C:\Users\User\Desktop\Vehicle_Damage_Detection")

DATA_YAML = PROJECT_ROOT / "data" / "processed" / "damaged_parts_yolo" / "data.yaml"
MODEL_PATH = PROJECT_ROOT / "models" / "base" / "yolo11s.pt"

model = YOLO(str(MODEL_PATH))

results = model.train(
    data=str(DATA_YAML),
    imgsz=768,
    epochs=80,
    batch=4,
    device=0,
    workers=0,
    
    name="damaged_parts_yolo11s_det_partbox_mirror_768"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.56 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.11.9 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from ultralytics import YOLO
from pathlib import Path

PROJECT_ROOT = Path(r"C:\Users\User\Desktop\Vehicle_Damage_Detection")

MODEL_PATH = PROJECT_ROOT / "notebooks" / "03_training" / "runs" / "detect" / "damaged_parts_yolo11s_det_partbox_mirror_768" / "weights" / "best.pt"

IMAGE_PATH = PROJECT_ROOT / "test_images" / "sample_car.jpg"

model = YOLO(str(MODEL_PATH))

results = model.predict(
    source=str(IMAGE_PATH),
    imgsz=768,
    conf=0.10,
    save=True
)
# Out:
# image 1/1 C:\Users\User\Desktop\Vehicle_Damage_Detection\test_images\sample_car.jpg: 448x768 (no detections), 55.9ms
# Speed: 5.9ms preprocess, 55.9ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 768)
# Results saved to C:\Users\User\Desktop\Vehicle_Damage_Detection\notebooks\03_training\runs\detect\predict
